# %%
# !pip install -q pandas numpy sentence-transformers faiss-cpu nltk scikit-learn

# %%
import json
import numpy as np
import pandas as pd
import faiss
import nltk
from sentence_transformers import SentenceTransformer
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
with open("Conversational_Transcript_Dataset.json") as f:
    data = json.load(f)

print("Total transcripts:", len(data["transcripts"]))
# Out:
# Total transcripts: 5037

# %%
records = []

for t in data["transcripts"]:
    text = ""
    for turn in t["conversation"]:
        text += f"{turn['speaker']}: {turn['text']} "

    records.append({
        "transcript_id": t["transcript_id"],
        "intent": t["intent"],
        "text": text
    })

df = pd.DataFrame(records)
df.head()
# Out:
#          transcript_id                                  intent  \
# 0  6794-8660-4606-3216                  Delivery Investigation
# 1  7034-5430-2980-5483  Escalation - Repeated Service Failures
# 2  1846-5500-2990-8975               Fraud Alert Investigation
# 3  1616-8531-3291-5075               Fraud Alert Investigation
# 4  7441-4348-3458-2384                   Account Access Issues
#
#                                                 text
# 0  Agent: Hello, thank you for contacting BuyNow....
# 1  Agent: Thank you for calling MedicalGroup. Thi...
# 2  Agent: Thank you for calling ProtectPlus Fraud...
# 3  Agent: Thank you for calling SecureBank Fraud ...
# 4  Agent: Thank you for calling DataLink. This is...

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(df["text"].tolist(), show_progress_bar=True)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches:   0%|          | 0/158 [00:00<?, ?it/s]

# %%
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))

# %%
def retrieve(query, k=4):
    q_emb = model.encode([query])
    _, idx = index.search(q_emb, k)
    return df.iloc[idx[0]]

# %%
complaint_keywords = [
    "delay", "problem", "issue", "again", "still",
    "not received", "waiting", "angry", "frustrated"
]

def extract_causal_signals(text):
    signals = {"repetition":0, "frustration":0, "agent_delay":0}

    for kw in complaint_keywords:
        signals["repetition"] += text.lower().count(kw)

    for segment in text.split("Customer:")[1:]:
        if sia.polarity_scores(segment)["compound"] < -0.3:
            signals["frustration"] += 1

    signals["agent_delay"] = max(0, text.count("Agent:") - text.count("Customer:"))
    return signals

# %%
def extract_evidence(text):
    evidence = []
    turns = text.split("Agent:")

    for t in turns:
        if "Customer:" in t:
            if sia.polarity_scores(t)["compound"] < -0.3:
                evidence.append("Customer:" + t.strip()[:200])

    for t in turns[:2]:
        if t.strip():
            evidence.append("Agent:" + t.strip()[:200])

    return evidence[:5]

# %%
def causal_explanation(query):
    results = retrieve(query)

    aggregate = {"repetition":0, "frustration":0, "agent_delay":0}

    for _, r in results.iterrows():
        sig = extract_causal_signals(r["text"])
        for k in aggregate:
            aggregate[k] += sig[k]

    explanation = []
    explanation.append("WHY THIS EVENT OCCURS:\n")

    if aggregate["repetition"] > 3:
        explanation.append("• Repeated unresolved customer issues")
    if aggregate["frustration"] > 2:
        explanation.append("• Escalating customer frustration")
    if aggregate["agent_delay"] > 2:
        explanation.append("• Delays or lack of resolution by agents")

    explanation.append("\nCAUSAL TRACE:")
    explanation.append("Repeated issue → Frustration → Escalation\n")

    explanation.append("EVIDENCE:\n")
    for _, r in results.iterrows():
        explanation.append(f"Transcript ID: {r['transcript_id']}")
        for e in extract_evidence(r["text"]):
            explanation.append(e)
        explanation.append("-"*40)

    explanation.append(f"\nConfidence: Supported by {len(results)} similar transcripts")

    return "\n".join(explanation)

# %%
print("\n" + "="*80)
print("TASK 1 OUTPUT — CAUSAL EXPLANATION")
print("="*80)

task1_query = "Why do customers escalate complaints?"
print(causal_explanation(task1_query))

print("\n" + "="*80)
print("END OF TASK 1")
print("="*80)
# Out:
# ================================================================================
# TASK 1 OUTPUT — CAUSAL EXPLANATION
# ================================================================================
# WHY THIS EVENT OCCURS:
#
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL TRACE:
# Repeated issue → Frustration → Escalation
#
# EVIDENCE:
#
# Transcript ID: 7461-4984-1291-5153
# Customer:Thank you for calling ShopEasy. This is Olivia. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is compl
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling ShopEasy. This is Olivia. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is compl
# ----------------------------------------
# Transcript ID: 2506-1813-2516-9541
# Customer:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# ----------------------------------------
# Transcript ID: 3853-4509-5928-6824
# Customer:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# ----------------------------------------
# Transcript ID: 6188-3939-9721-1704
# Customer:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# ----------------------------------------
#
# Confidence: Supported by 4 similar transcripts
#
# ================================================================================
# END OF TASK 1
# ================================================================================

# %%
memory = {
    "last_query": None,
    "last_results": None
}

# %%
def is_followup(query):

    if memory["last_query"] is None:
        return False

    v1 = model.encode([query])
    v2 = model.encode([memory["last_query"]])

    similarity = float(np.dot(v1, v2.T))

    return similarity > 0.7

# %%
import warnings
warnings.filterwarnings("ignore")

def format_chat_response(query, explanation, is_followup=False):

    lines = explanation.split("\n")

    print("\n" + "="*80)

    if not is_followup:
        print("ASSISTANT:")
        print(f"I understand your question:\n→ \"{query}\"\n")
        print("Here’s what’s happening based on similar conversations:\n")
    else:
        print("ASSISTANT:")
        print("Good follow-up question.\n")
        print("Looking at similar past cases, this issue keeps happening because:\n")

    for line in lines:
        if line.startswith("•") or "WHY THIS EVENT OCCURS" in line:
            print(line)

    print("\nCAUSAL FLOW:")
    for line in lines:
        if "→" in line:
            print(line)

    print("\nSUPPORTING EXAMPLES:")
    shown = 0

    for line in lines:
        if line.startswith("Transcript ID"):
            print(line)

        if line.startswith("Customer:") or line.startswith("Agent:"):
            print(line)
            shown += 1

        if is_followup and shown >= 3:
            break

    print("\n" + "="*80)

# %%
def chat(query):

    followup = is_followup(query)

    if followup:
        results = memory["last_results"]
    else:
        results = retrieve(query)
        memory["last_query"] = query
        memory["last_results"] = results

    explanation = causal_explanation(query)

    format_chat_response(
        query=query,
        explanation=explanation,
        is_followup=followup
    )

# %%
query_df = pd.read_csv("query_dataset.csv")

print("\nTotal Queries Loaded:", len(query_df))
query_df.head()
# Out:
# Total Queries Loaded: 10
#   query_id                                       query_text  \
# 0       Q1            Why do customers escalate complaints?
# 1       Q2        What causes repeated customer complaints?
# 2       Q3  Why are customers asking for managers so often?
# 3       Q4            Why do customers escalate complaints?
# 4       Q5              Why does this happen so frequently?
#
#         expected_intent task_type is_followup  \
# 0  complaint_escalation     task1          no
# 1  complaint_escalation     task1          no
# 2  complaint_escalation     task1          no
# 3  complaint_escalation     task2          no
# 4  complaint_escalation     task2         yes
#
#                               notes
# 0  Primary causal explanation query
# 1          Checks repetition signal
# 2                Escalation trigger
# 3                Initial chat query
# 4        Follow-up relies on memory

# %%
for _, row in query_df.iterrows():

    print("\n" + "="*80)
    print(f"QUERY ID: {row['query_id']}")
    print(f"QUERY: {row['query_text']}")

    if row["task_type"] == "task1":

        print("\n[TASK 1 OUTPUT]")
        print(causal_explanation(row["query_text"]))

    elif row["task_type"] == "task2":

        print("\n[TASK 2 OUTPUT]")
        chat(row["query_text"])
# Out:
# ================================================================================
# QUERY ID: Q1
# QUERY: Why do customers escalate complaints?
#
# [TASK 1 OUTPUT]
# WHY THIS EVENT OCCURS:
#
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL TRACE:
# Repeated issue → Frustration → Escalation
#
# EVIDENCE:
#
# Transcript ID: 7461-4984-1291-5153
# Customer:Thank you for calling ShopEasy. This is Olivia. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is compl
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling ShopEasy. This is Olivia. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is compl
# ----------------------------------------
# Transcript ID: 2506-1813-2516-9541
# Customer:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# ----------------------------------------
# Transcript ID: 3853-4509-5928-6824
# Customer:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# ----------------------------------------
# Transcript ID: 6188-3939-9721-1704
# Customer:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# ----------------------------------------
#
# Confidence: Supported by 4 similar transcripts
#
# ================================================================================
# QUERY ID: Q2
# QUERY: What causes repeated customer complaints?
#
# [TASK 1 OUTPUT]
# WHY THIS EVENT OCCURS:
#
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL TRACE:
# Repeated issue → Frustration → Escalation
#
# EVIDENCE:
#
# Transcript ID: 3853-4509-5928-6824
# Customer:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# ----------------------------------------
# Transcript ID: 2506-1813-2516-9541
# Customer:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# ----------------------------------------
# Transcript ID: 6188-3939-9721-1704
# Customer:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# ----------------------------------------
# Transcript ID: 6037-1189-7358-2962
# Customer:Thank you for calling ShopEasy. This is David. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complet
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling ShopEasy. This is David. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complet
# ----------------------------------------
#
# Confidence: Supported by 4 similar transcripts
#
# ================================================================================
# QUERY ID: Q3
# QUERY: Why are customers asking for managers so often?
#
# [TASK 1 OUTPUT]
# WHY THIS EVENT OCCURS:
#
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL TRACE:
# Repeated issue → Frustration → Escalation
#
# EVIDENCE:
#
# Transcript ID: 7230-3385-4522-8358
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending incorrec
# Agent:Thank you for calling HotelPrime. This is Emily. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is compl
# ----------------------------------------
# Transcript ID: 7759-2660-9121-2321
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending incorrec
# Agent:Thank you for calling HotelPrime. This is Joshua. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is comp
# ----------------------------------------
# Transcript ID: 7552-6299-5982-6654
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending incorrec
# Agent:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is comp
# ----------------------------------------
# Transcript ID: 5306-7322-7633-7457
# Agent:Thank you for calling HotelPrime. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is comple
# ----------------------------------------
#
# Confidence: Supported by 4 similar transcripts
#
# ================================================================================
# QUERY ID: Q4
# QUERY: Why do customers escalate complaints?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Why do customers escalate complaints?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 7461-4984-1291-5153
# Customer:Thank you for calling ShopEasy. This is Olivia. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is compl
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling ShopEasy. This is Olivia. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is compl
# Transcript ID: 2506-1813-2516-9541
# Customer:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling DirectShop. This is Ashley. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Transcript ID: 3853-4509-5928-6824
# Customer:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# Transcript ID: 6188-3939-9721-1704
# Customer:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending damaged
# Agent:Thank you for calling RetailPro. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is com
#
# ================================================================================
#
# ================================================================================
# QUERY ID: Q5
# QUERY: Why does this happen so frequently?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Why does this happen so frequently?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 3162-9234-3378-3859
# Customer:The appointment is showing in our reminder system but not in Dr. Harrison's actual schedule. We had a software update about two weeks ago and there may have been a synchronization error. Customer: So
# Customer:I completely understand your frustration, and this is entirely our fault. Let me contact Dr. Harrison's nurse to see if we can accommodate you today. Customer: Please, because I really need to see the
# Agent:City Medical Center, this is Samuel speaking. How can I help you? Customer: Yes, I'm at your clinic right now for my 2 o'clock appointment with Dr. Harrison, but the front desk says I'm not in the sys
# Transcript ID: 4110-4036-4702-6062
# Customer:The appointment is showing in our reminder system but not in Dr. Harrison's actual schedule. We had a software update about two weeks ago and there may have been a synchronization error. Customer: So
# Customer:I completely understand your frustration, and this is entirely our fault. Let me contact Dr. Harrison's nurse to see if we can accommodate you today. Customer: Please, because I really need to see the
# Agent:City Medical Center, this is Michelle speaking. How can I help you? Customer: Yes, I'm at your clinic right now for my 2 o'clock appointment with Dr. Harrison, but the front desk says I'm not in the s
# Transcript ID: 6284-5963-3990-4924
# Customer:The appointment is showing in our reminder system but not in Dr. Harrison's actual schedule. We had a software update about two weeks ago and there may have been a synchronization error. Customer: So
# Customer:I completely understand your frustration, and this is entirely our fault. Let me contact Dr. Harrison's nurse to see if we can accommodate you today. Customer: Please, because I really need to see the
# Agent:City Medical Center, this is Jason speaking. How can I help you? Customer: Yes, I'm at your clinic right now for my 2 o'clock appointment with Dr. Harrison, but the front desk says I'm not in the syst
# Transcript ID: 2226-3326-9450-6963
# Customer:The appointment is showing in our reminder system but not in Dr. Harrison's actual schedule. We had a software update about two weeks ago and there may have been a synchronization error. Customer: So
# Customer:I completely understand your frustration, and this is entirely our fault. Let me contact Dr. Harrison's nurse to see if we can accommodate you today. Customer: Please, because I really need to see the
# Agent:City Medical Center, this is David speaking. How can I help you? Customer: Yes, I'm at your clinic right now for my 2 o'clock appointment with Dr. Harrison, but the front desk says I'm not in the syst
#
# ================================================================================
#
# ================================================================================
# QUERY ID: Q6
# QUERY: Why are customers so frustrated?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Why are customers so frustrated?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 7205-5946-9363-3595
# Customer:Thank you for calling ShopEasy. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a broken device. This is comple
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending broken d
# Agent:Thank you for calling ShopEasy. This is Jessica. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a broken device. This is comple
# Transcript ID: 1948-8828-1791-6830
# Customer:Thank you for calling ShopEasy. This is Richard. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a broken device. This is comple
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending broken d
# Agent:Thank you for calling ShopEasy. This is Richard. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a broken device. This is comple
# Transcript ID: 1655-5564-7436-7550
# Customer:Thank you for calling ShopEasy. This is William. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a broken device. This is comple
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending broken d
# Agent:Thank you for calling ShopEasy. This is William. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a broken device. This is comple
# Transcript ID: 3853-4509-5928-6824
# Customer:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling ShopEasy. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is complete
#
# ================================================================================
#
# ================================================================================
# QUERY ID: Q7
# QUERY: Why do unresolved issues lead to escalation?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Why do unresolved issues lead to escalation?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 3852-7465-5433-7878
# Agent:Thank you for calling SoftwarePro technical support. This is Brian. How can I assist you? Customer: Hi, I updated my development tool yesterday and now it displays a critical failure message I try to
# Transcript ID: 2901-8052-5076-7781
# Agent:Thank you for calling TechSolutions technical support. This is Amanda. How can I assist you? Customer: Hi, I updated my development tool yesterday and now it displays a critical failure message I try
# Transcript ID: 4172-6690-3883-7159
# Agent:Thank you for calling TechHelp technical support. This is Laura. How can I assist you? Customer: Hi, I updated my development tool yesterday and now it displays a critical failure message I try to lau
# Transcript ID: 3597-7922-1064-5945
# Agent:Thank you for calling DigitalSupport technical support. This is Sarah. How can I assist you? Customer: Hi, I updated my development tool yesterday and now it displays a critical failure message I try
#
# ================================================================================
#
# ================================================================================
# QUERY ID: Q8
# QUERY: Is agent delay a reason for escalation?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Is agent delay a reason for escalation?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 5798-1198-4201-1549
# Customer:Thank you for calling FastShip. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a missing items. This is completel
# Agent:Thank you for calling FastShip. This is Lisa. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a missing items. This is completel
# Transcript ID: 9962-7109-7141-4925
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending incorrec
# Agent:Thank you for calling FastShip. This is Brian. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is complet
# Transcript ID: 9658-4994-7196-5929
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending incorrec
# Agent:Thank you for calling FastShip. This is Thomas. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is comple
# Transcript ID: 7269-3117-7104-2296
# Agent:Thank you for calling FastShip. This is Sean. How may I assist you today? Customer: I need to speak with a manager immediately. This is the four time you've sent me a incorrect order. This is complete
#
# ================================================================================
#
# ================================================================================
# QUERY ID: Q9
# QUERY: Why does the same issue keep happening?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Why does the same issue keep happening?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 6282-5084-7444-1507
# Agent:Thank you for calling DeviceCare technical support. This is Lisa. How can I assist you? Customer: Hi, I updated my design software yesterday and now it freezes during startup I try to launch it.
# Transcript ID: 9384-6967-6273-4457
# Agent:Thank you for calling SoftwarePro technical support. This is Christopher. How can I assist you? Customer: Hi, I updated my design software yesterday and now it crashes every single time I try to launc
# Transcript ID: 9446-9115-8825-7053
# Agent:Thank you for calling DeviceCare technical support. This is Joshua. How can I assist you? Customer: Hi, I updated my design software yesterday and now it freezes during startup I try to launch it.
# Transcript ID: 3234-8643-7015-3823
# Agent:Thank you for calling TechHelp technical support. This is Laura. How can I assist you? Customer: Hi, I updated my design software yesterday and now it crashes every single time I try to launch it.
#
# ================================================================================
#
# ================================================================================
# QUERY ID: Q10
# QUERY: Why do customers lose trust after repeated issues?
#
# [TASK 2 OUTPUT]
#
# ================================================================================
# ASSISTANT:
# I understand your question:
# → "Why do customers lose trust after repeated issues?"
#
# Here’s what’s happening based on similar conversations:
#
# WHY THIS EVENT OCCURS:
# • Repeated unresolved customer issues
# • Escalating customer frustration
# • Delays or lack of resolution by agents
#
# CAUSAL FLOW:
# Repeated issue → Frustration → Escalation
#
# SUPPORTING EXAMPLES:
# Transcript ID: 1382-6000-5474-8781
# Customer:Thank you for calling TrustFinancial. This is Nicole. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending defectiv
# Agent:Thank you for calling TrustFinancial. This is Nicole. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a defective item. This is
# Transcript ID: 3046-8935-6811-3952
# Customer:Thank you for calling TrustFinancial. This is Charles. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This i
# Agent:Thank you for calling TrustFinancial. This is Charles. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This i
# Transcript ID: 3617-5951-7618-1826
# Customer:Thank you for calling TrustFinancial. This is Sarah. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is
# Agent:Thank you for calling TrustFinancial. This is Sarah. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a damaged product. This is
# Transcript ID: 6283-9308-6922-8160
# Customer:Thank you for calling TrustFinancial. This is Scott. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a missing items. This is co
# Customer:I'm very sorry to hear about this issue. I'd be happy to help you resolve this right away. Can you tell me more about what happened? Customer: What happened is that your company keeps sending missing
# Agent:Thank you for calling TrustFinancial. This is Scott. How may I assist you today? Customer: I need to speak with a manager immediately. This is the three time you've sent me a missing items. This is co
#
# ================================================================================
